# %% [markdown]
# # Resume Screening Demo
# Machine Learning Task 3 (Future Interns): rank candidates against a job description using NLP.

# %%
import pandas as pd
from src.pipeline import ResumeScreeningPipeline

# %%
pipeline = ResumeScreeningPipeline()
artifacts = pipeline.run(
    resumes_path='data/raw/resumes_sample.csv',
    job_description_path='data/raw/job_description_data_scientist.txt',
    role='data_scientist',
    output_dir='data/processed'
)
artifacts

# %%
pd.read_csv('data/processed/candidate_ranking.csv').head(10)
